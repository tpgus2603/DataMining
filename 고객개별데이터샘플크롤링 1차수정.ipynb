# %% [markdown]
# <a href="https://colab.research.google.com/github/tpgus2603/DataMining/blob/main/%EA%B3%A0%EA%B0%9D%EA%B0%9C%EB%B3%84%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%83%98%ED%94%8C%ED%81%AC%EB%A1%A4%EB%A7%81%201%EC%B0%A8%EC%88%98%EC%A0%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Python 패키지 설치
# !pip install selenium pandas numpy beautifulsoup4 requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 51.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.7/481.7 kB 29.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import os

# 패키지 임포트
import selenium
from selenium import webdriver
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By # 셀레니움 4.0부터 포함된 함수(필수)
import time
from selenium.webdriver.common.keys import Keys

from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# %%
import requests

url = 'https://www.coupang.com'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0120.0.0.0 Safari/537.36", "Accept-Language": "ko-KR,ko;q=0.8,en-US;q=0.5,en;q=0.3"}
res = requests.get(url, headers=headers)
html = res.text

# %%
import bs4
bs_obj = bs4.BeautifulSoup(html, 'html.parser')
print(bs_obj.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 7 ]><html class="lt-ie9 lt-ie8" lang="ko-KR"><![endif]-->
# <!--[if IE 8 ]><html class="lt-ie9" lang="ko-KR"><![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!-->
# <html lang="ko-KR">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" name="google-site-verification"/>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="//cart.coupang.com" rel="dns-prefetch"/>
#   <link href="//assets.coupang.com" rel="dns-prefetch"/>
#   <link href="//assets2.coupang.com" rel="dns-prefetch"/>
#   <link href="//assets.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//asset1.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//private.coupang.com" rel="dns-prefetch"/>
#   <link href="//img1a.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//image1.coupangcdn.com" rel="dns-prefetch"/>
#   <link href="//thumbnail1.coupangcdn.com" rel="dns-prefetch"/>
# ...

# %%
# 두번째 depth categories
second_category = []
first = bs_obj.select('#gnbAnalytics > ul.menu.shopping-menu-list > li')

for f in first:
    category = f.find('a').text
    second = f.findAll('li', {'class': 'second-depth-list'})
    for s in second:
        second_cat = s.find('a').text
        if second_cat == '더보기':
            continue
        second_category.append(second_cat)


print(second_category)
# Out:
# ['여성패션 ', '남성패션 ', '남녀 공용 의류 ', '속옷/잠옷 ', '유아동패션 ', 'R.LUX ', '스킨케어 ', '클린/비건뷰티 ', '클렌징/필링 ', '더마코스메틱 ', '메이크업 ', '향수 ', '남성화장품 ', '네일 ', '뷰티소품 ', '어린이화장품 ', '로드샵 ', '헤어 ', '바디 ', '선물세트/키트 ', '유아동패션 ', '기저귀 ', '물티슈 ', '분유/어린이식품 ', '어린이 건강식품 ', '수유용품 ', '이유용품/유아식기 ', '매트/안전용품 ', '유모차/웨건 ', '카시트 ', '아기띠/외출용품 ', '욕실용품/스킨케어 ', '위생/건강/세제 ', '유아동침구 ', '유아가구/인테리어 ', '완구/교구 ', '유기농/친환경 전문관 ', '과일 ', '견과/건과 ', '채소 ', '쌀/잡곡 ', '축산/계란 ', '수산물/건어물 ', '생수/음료 ', '커피/원두/차 ', '과자/초콜릿/시리얼 ', '면/통조림/가공식품 ', '가루/조미료/오일 ', '장/소스/드레싱/식초 ', '유제품/아이스크림 ', '냉장/냉동/간편요리 ', '건강식품 ', '주방가전 ', '냄비/프라이팬 ', '주방조리도구 ', '그릇/홈세트 ', '수저/커트러리 ', '컵/텀블러/와인용품 ', '주전자/커피/티용품 ', '주방수납/정리 ', '밀폐저장/도시락 ', '주방잡화 ', '일회용품/종이컵 ', '보온/보냉용품 ', '1인가구 주방용품 ', '헤어 ', '바디/세안 ', '구강/면도 ', '화장지/물티슈 ', '생리대/성인용기저귀 ', '기저귀 ', '세탁세제 ', '청소/주방세제 ', '탈취/방향/살충 ', '건강/의료용품 ', '성인용품(19) ', '세탁/청소용품 ', '욕실용품 ', '생활전기용품 ', '수납/정리 ', '주방수납/잡화 ', '크리스마스용품 ', '방한용품 ', 'F/W 침구샵 ', '싱글하우스 ', '홈데코 ', '가구 ', '수납/정리 ', '침구 ', '커튼/블라인드 ', '카페트/쿠션/거실화 ', 
# ...

# %%
# ChromeDriver 다운로드
# !wget https://mirrors.huaweicloud.com/chromedriver/131.0.6778.85/chromedriver-linux64.zip
# 최신 Google Chrome 설치
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb || apt-get -fy install
# 압축 해제
# !unzip chromedriver-linux64.zip

# chromedriver 실행 파일 이동
# !mv chromedriver-linux64/chromedriver /usr/local/bin/chromedriver

# 실행 권한 부여
# !chmod +x /usr/local/bin/chromedriver
# Out:
# --2024-12-02 15:36:50--  https://mirrors.huaweicloud.com/chromedriver/131.0.6778.85/chromedriver-linux64.zip
# Resolving mirrors.huaweicloud.com (mirrors.huaweicloud.com)... 120.46.63.139, 1.92.76.132, 120.46.2.67, ...
# Connecting to mirrors.huaweicloud.com (mirrors.huaweicloud.com)|120.46.63.139|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 9925053 (9.5M) [application/octet-stream]
# Saving to: ‘chromedriver-linux64.zip’
#
# chromedriver-linux6 100%[===================>]   9.46M  3.74MB/s    in 2.5s
#
# 2024-12-02 15:36:54 (3.74 MB/s) - ‘chromedriver-linux64.zip’ saved [9925053/9925053]
#
# Archive:  chromedriver-linux64.zip
#   inflating: chromedriver-linux64/LICENSE.chromedriver
#   inflating: chromedriver-linux64/THIRD_PARTY_NOTICES.chromedriver
#   inflating: chromedriver-linux64/chromedriver

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# Chrome 옵션 설정
options = Options()
options.add_argument('--headless')  # 헤드리스 모드 실행
options.add_argument('--no-sandbox')  # 보안 샌드박스 비활성화
options.add_argument('--disable-dev-shm-usage')  # 공유 메모리 사용 비활성화
options.add_argument('--remote-debugging-port=9222')  # 원격 디버깅 포트 활성화

# Chrome 바이너리 경로 명시
options.binary_location = "/usr/bin/google-chrome"

# ChromeDriver 실행 경로 설정
chrome_service = Service('/usr/local/bin/chromedriver')

# WebDriver 생성
driver = webdriver.Chrome(service=chrome_service, options=options)

# URL 접근
url = 'https://www.coupang.com/vp/products/7645962236?itemId=20330122766&vendorItemId=87415272296&sourceType=CATEGORY&categoryId=186664&isAddedCart=#sdpReview'
driver.get(url)
print(driver.title)  # 페이지 제목 출력
# Out:
# www.coupang.com

# %%
url = 'https://www.coupang.com/vp/products/7645962236?itemId=20330122766&vendorItemId=87415272296&sourceType=CATEGORY&categoryId=186664&isAddedCart=#sdpReview'

driver.get(url)
print(driver.title)  # 페이지 제목 출력
# Out:
# www.coupang.com

# %%
driver.find_element(By.XPATH, '//*[@id="prod-review-nav-link"]/span[2]').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-37-f993ad8c02fe> in <cell line: 1>()
# ----> 1 driver.find_element(By.XPATH, '//*[@id="prod-review-nav-link"]/span[2]').click()
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     768             return elements[0]
#     769
# --> 770         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     771
#     772     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     382         response = self.command_executor.execute(driver_command, params)
#     383         if response:
# --> 384             self.error_handler.check_response(response)
# ...

# %%
driver.find_element(By.XPATH, '//*[@id="btfTab"]/ul[2]/li[2]/div/div[6]/section[4]/article[1]/div[1]/div[1]/img').click()

# %%
cust1 = driver.find_element(By.CLASS_NAME, 'sdp-review__profile__article__list.js_reviewProfileModalReviewListContainer')

# %% [markdown]
# 스크롤 끝까지 내리기

# %%
cust1 = cust1.find_elements(By.CLASS_NAME, 'sdp-review__profile__article__list__reviews')

# %%
cust1_review_data = []
for review in cust1:
    product_name = review.find_element(By.CLASS_NAME, 'sdp-review__profile__article__list__reviews__product__name').text
    rating = review.find_element(By.CLASS_NAME, 'sdp-review__profile__article__list__reviews__star__orange.js_reviewProfileModalReviewRating').get_attribute('data-rating')
    review_title = review.find_element(By.CLASS_NAME, 'sdp-review__profile__article__list__reviews__title').text
    review_content = review.find_element(By.CLASS_NAME, 'sdp-review__profile__article__list__reviews__content').text
    print([product_name, rating, review_title, review_content])
    cust1_review_data.append([product_name, rating, review_title, review_content])
# Out:
# ['나이키 브라질리아 9.5 트레이닝 더플백 + 이너백, XS, 블랙', '5', '❝ 쓰임새 좋은 튼튼한 나이키 더플백 ❞', '• 사이즈 - XS (38x25x25cm)\n이너백 사이즈 - 19x33cm\n\n• 수납용량 - 25L\n\n이전부터 이런 망치가방 하나 있었으면 했는데,\n마침 나이키 더플백이 사이즈나 쓰임새가 딱이네요!\n개인적으로 각 안잡히고 흐물거리는 가방을 좋아하지 않는데,\n이건 이너백이 있어서 예쁘게 각이 잡히네요 ^^\n\n처음 봤을땐 생각보다 사이즈가 작은것 같았는데\n실제로 사용하다보면 수납력이 좋아 전혀 작다고 느껴지지 않네요\n\n헬스나 운동은 따로 다니지 않아서\n여행이나 외출용으로 딱 원하던 가방이에요\n25L 수납 가능한 사이즈라서 굉장히 넉넉해서 이것저것 다들어가요\n1인 여행용으로는 옷이랑 세면도구, 수건 등등 아주 넉넉히 들어가고 남고\n2인 옷까지도 다 들어갈 정도로 수납력 아주 좋아요\n\n사진은 건장한 성인 남자가 어깨에 맸을때,\n작은 체구 여자가 어깨에 맸을때랑 손으로 들었을때 보여지는 크기에요\n\n성인남자한테 XS 사이즈는 카메라가방 맨것처럼 보이고\n성인여성이나 아이들이 크로스로 매는게 개인적으로 사이즈 딱 예뻐보이네요\n남자분들도 간편하게 가지고 다닐 수 있는 헬스가방 찾으시면 사이즈 좋아요~\n\n가방 양 옆, 앞으로도 외부에 포켓이 있어서 이것저것 수납하기 좋고\n매쉬망 포켓에는 텀블러 넣어두면 고정력 좋네요\n오른쪽 외부 포켓은 운동화나 슬리퍼도 수납이 가능해요\n사이즈 260까지는 충분히 넣을 수 있을 정도네요\n대신 포켓이 가방 안쪽으로 수납공간이 확보되니 신발을 넣으면\n가방 안쪽 수납공간은 그만큼 줄어드니 참고하세요!\n\n숄더 스트랩은 XS, S 사이즈는 고정형이라 탈부착 안되고\nM사이즈부터 탈부착 가능해요\n근데 탈부착 가능해도 굳이 떼어놓지 않을것 같아서 불편함은 안느껴지네요\n\n지퍼가 물 닿아도 녹슬지 않는 재질인것 같아 이것도 아주 마음에 들어요\n가방 자체는 폴리에스터
# ...

# %%
len(cust1_review_data)
# Out:
# 299

# %%
driver.close()

# %%
reviews_category = []
from selenium.webdriver.common.keys import Keys
for reviews in cust1_review_data:
    try:
        url = 'https://www.coupang.com/vp/products/5065583446?itemId=2370722819&vendorItemId=3510662496&sourceType=CATEGORY&categoryId=186664&isAddedCart='
        driver = webdriver.Chrome()
        driver.get(url)
        driver.set_window_size(500, 500)
        search = driver.find_element(By.ID, 'headerSearchKeyword')
        product = reviews[0].split(',')[0]
        search.send_keys(product)
        search.send_keys(Keys.ENTER)
        time.sleep(5)

        # try:
        first_product = driver.find_element(By.CLASS_NAME, "search-product-link").get_attribute('href')
        url = first_product
        print(url)
        driver.close()


        # import requests
        # headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0120.0.0.0 Safari/537.36", "Accept-Language": "ko-KR,ko;q=0.8,en-US;q=0.5,en;q=0.3"}
        # res = requests.get(url, headers=headers)
        # html = res.text
        # import bs4
        # bs_obj = bs4.BeautifulSoup(html, 'html.parser')

        driver = webdriver.Chrome()
        driver.get(url)
        driver.set_window_size(500, 500)
        time.sleep(10)

        categories = driver.find_elements(By.CLASS_NAME, 'breadcrumb-link')
        print(categories)

        try:
            categories[1].text
            categories[2].text
            reviews.append(categories[1].text)
            reviews.append(categories[2].text)
            reviews_category.append(reviews)
        except:
            continue

        driver.close()
    except:
        continue
# Out:
# https://www.coupang.com/vp/products/7728016919?itemId=20758588136&vendorItemId=87828059178&sourceType=srp_product_ads&clickEventId=a5e26120-b799-11ee-9754-9887ea79846f&korePlacement=15&koreSubPlacement=1&clickEventId=a5e26120-b799-11ee-9754-9887ea79846f&korePlacement=15&koreSubPlacement=1&q=%EB%82%98%EC%9D%B4%ED%82%A4+%EB%B8%8C%EB%9D%BC%EC%A7%88%EB%A6%AC%EC%95%84+9.5+%ED%8A%B8%EB%A0%88%EC%9D%B4%EB%8B%9D+%EB%8D%94%ED%94%8C%EB%B0%B1+++%EC%9D%B4%EB%84%88%EB%B0%B1&itemsCount=36&searchId=1392c20582b744838903532d3804e85f&rank=0
# ...

# %%
reviews_category
# Out:
# [['나이키 브라질리아 9.5 트레이닝 더플백 + 이너백, XS, 블랙',
#   '5',
#   '❝ 쓰임새 좋은 튼튼한 나이키 더플백 ❞',
# ...

# %%
for review in reviews_category:
    if (review[5] not in second_category):
        reviews_category.remove(review)

# %%
cust1 = pd.DataFrame(reviews_category, columns=['상품명', '별점', '리뷰 제목', '리뷰 내용', '카테고리1', '카테고리2'])
cust1
# Out:
#                                                    상품명 별점  \
# 0                                농우 타코야끼 (냉동), 1kg, 1개  5
# 1                       스넬 식기세척기 세제 올인원 30개입 600g, 20g  5
# 2                                국내산 미니 파프리카, 200g, 1개  5
# 3                                     국내산 부추, 300g, 1개  5
# 4                             한성기업 몬스터크랩 맛살, 142g, 2개입  5
# ..                                                 ... ..
# 141          연세대학교 관절건강 판매 1위 팔팔한 진득찰 보스웰리아, 70ml, 30개  5
# 142                 제이멜라 인 프랑스 페이보릿 퍼퓸 핸드크림 5종 세트, 1세트  5
# 143  흠뻑 국내산 한우 1++ 투뿔 마장동 소고기 선물세트 구이용 1kg 백화점 상견례,...  5
# 144  로더렛 인 잉글랜드 컬러핏 파우더리 브리즈 바디 워시 베이비 파우더향, 1개, 500ml  5
# 145                 로더렛 컬러 핏 그레이스 머스크 바디 워시 1000ml, 1개  5
#
#                          리뷰 제목  \
# 0      ❝ 제일 저렴한데 제일 맛있는 타코야끼 ❞
# 1    ❝ 물자국 없이 깨끗한 스넬 올인원 세척제 ❞
# 2    ❝ 앙증맞은 사이즈의 국내산 미니 파프리카 ❞
# 3          ❝ 마트보다 싸게산 국내산 부추 ❞
# 4    ❝ 결대로 찢어지는 쫄깃한 몬스터크랩 맛살 ❞
# ..                         ...
# 141                달달해서 먹기 편해요
# ...

# %%
# cust1.to_csv('../json_csv_files/sample_customer_data/cust6.csv', index=False, encoding='utf-8-sig')

# %%
import os

 = os.listdir('../json_csv_files/sample_customer_data/')
reviews
# Out:
# ['.ipynb_checkpoints',
#  'cust1.csv',
#  'cust10.csv',
#  'cust2.csv',
#  'cust3.csv',
#  'cust4.csv',
#  'cust5.csv',
#  'cust6.csv',
#  'cust7.csv',
#  'cust8.csv',
#  'cust9.csv']

# %%
import pandas as pd
customers = pd.DataFrame()
reviews = reviews[1:]
for review in reviews:
    df = pd.read_csv('../json_csv_files/sample_customer_data/' + review)
    df['userid'] = review.split('.')[0]
    customers = pd.concat([customers, df])
customers
# Out:
#                              상품명  별점                         리뷰 제목  \
# 0              국내산 시금치, 200g, 1개   5                         아삭해요~
# 1          리한 오뚝이 롤리 주걱, 화이트, 1개   5                 위생적이고 엄청 편해요~
# 2                밀양 깻잎, 100g, 1개   5                       향이 좋아요~
# 3               국내산 양배추, 1개입, 1개   5                         달콤해요~
# 4               국내산 부추, 300g, 1개   5                       파릇파릇해요~
# ..                           ...  ..                           ...
# 61       오뚜기 맛있는 오뚜기밥, 210g, 36개   5  변경한 즉석밥! 가격으로 맛으로 승부보다! GET!
# 62  허브타임 차량용 디퓨저 60ml, 레몬그라스, 1개   5     은은한 레몬그라스향, 차량에 어울리는 상큼함!
# 63                 햇반, 210g, 36개   5       가격제일 저렴하고, 믿을수있는 즉석밥1위!
# 64    대림선 부산 어묵 마당놀이2, 1000g, 1개   5    부산어묵 국물좋고, 맛좋고, 다양하게 요리하고!
# 65       곰곰 대패삼겹살 (냉동), 500g, 3개   5     가격이 매력적! 소분되어 다양한 요리에 적합!
#
#                                                 리뷰 내용    카테고리1       카테고리2  \
# 0   ◈ 제품명 : 국내산 시금치, 200g, 1개\n◈ 구매일자 : 2023.12.30...  헬스/건강식품   곤약/방탄커피 외
# ...

# %%
customers['userid'].unique()
# Out:
# array(['cust1', 'cust10', 'cust2', 'cust3', 'cust4', 'cust5', 'cust6',
#        'cust7', 'cust8', 'cust9'], dtype=object)

# %%
customers.to_csv('../json_csv_files/customers10_data.csv', index=False, encoding='utf-8-sig')
